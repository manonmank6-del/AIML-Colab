# %% [markdown]
# <a href="https://colab.research.google.com/github/manonmank6-del/AIML-Colab/blob/main/randam_forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45b2201d-b4b9-4c4d-bcea-5e9127d05858" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45b2201d-b4b9-4c4d-bcea-5e9127d05858">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('Model Sample Data - Retail Inventory.xlsx')

# %%
import pandas as pd

# The file 'Model Sample Data - Retail Inventory.xlsx' was uploaded.
df = pd.read_excel('Model Sample Data - Retail Inventory.xlsx')

display(df.head())
# Out:
#                             Store Location (i) Product  \
# 0                                            1      p1
# 1  Distance from Centralized Disposal Facility      p5
# 2                                          NaN      p8
# 3                                          NaN     p16
# 4                                          NaN     p17
#
#   Volume per unit of product (cm3) Beginning Inventory (Bipi, pc)  \
# 0                              469                             30
# 1                               72                            136
# 2                              366                             48
# 3                              393                             96
# 4                              121                             23
#
#   Lower Maintaining Inventory Level (LMILpi, pc)  \
# 0                                             47
# 1                                             20
# 2                                             49
# ...

# %%
df = pd.read_excel('Model Sample Data - Retail Inventory.xlsx')

# %%
display(df.describe())
# Out:
#        Unnamed: 16  \
# count      30.0000
# mean      795.0000
# std       361.1834
# min       400.0000
# 25%       500.0000
# 50%       660.0000
# 75%      1000.0000
# max      1500.0000
#
#        REMOVED PRODUCTS: 2,3,4,6,7,9,10,11,12,14,15,13,19,20,22,23, 24, 25, 26  \
# count                                           9.000000
# mean                                            3.333333
# std                                             2.500000
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             8.000000
#
#        Unnamed: 21
# count     9.000000
# mean      0.333333
# std       0.250000
# min       0.100000
# 25%       0.100000
# 50%       0.400000
# 75%       0.500000
# max       0.800000

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'extracted_data', 'Model Sample Data - Retail Inventory (1) (2).xlsx', 'Model Sample Data - Retail Inventory (1) (1).xlsx', 'Model Sample Data - Retail Inventory.xlsx', 'Model Sample Data - Retail Inventory (1).xlsx', 'Model Sample Data - Retail Inventory (3).xlsx', 'Model Sample Data - Retail Inventory (2).xlsx', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'extracted_data', 'Model Sample Data - Retail Inventory (1) (2).xlsx', 'Model Sample Data - Retail Inventory (1) (1).xlsx', 'Model Sample Data - Retail Inventory.xlsx', 'Model Sample Data - Retail Inventory (1).xlsx', 'Model Sample Data - Retail Inventory (3).xlsx', 'Model Sample Data - Retail Inventory (2).xlsx', 'sample_data']

# %%
print("Missing values in each column:\n")
display(df.isnull().sum())
# Out:
# Missing values in each column:
# Store Location (i)                                                         18
# Product                                                                     3
# Volume per unit of product (cm3)                                            3
# Beginning Inventory (Bipi, pc)                                              3
# Lower Maintaining Inventory Level (LMILpi, pc)                              3
# Expected Maintaining Inventory Level (EMILpi, pc)                           3
# Upper Maintaining Inventory Level (UMILpi, pc)                              3
# Product category (from Phase 1)                                             3
# selling price (sp, Php/pc)                                                  3
# cost (cp, Php/pc)                                                           3
# disposal cost (disppi, Php/pc)                                              3
# transport cost (tpi, Php/pc)                                                3
# ...

# %% [markdown]
# The output above shows the number of missing values (NaN, None, or similar) for each column in your DataFrame. A higher number indicates more missing data in that particular column. This information is crucial for deciding on data cleaning strategies, such as imputation or removal of rows/columns.

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'extracted_data', 'Model Sample Data - Retail Inventory (1) (2).xlsx', 'Model Sample Data - Retail Inventory (1) (1).xlsx', 'Model Sample Data - Retail Inventory.xlsx', 'Model Sample Data - Retail Inventory (1).xlsx', 'Model Sample Data - Retail Inventory (3).xlsx', 'Model Sample Data - Retail Inventory (2).xlsx', 'sample_data']

# %%
import numpy as np

# List of columns identified as numerical but currently of object type
columns_to_convert = [
    'Volume per unit of product (cm3)',
    'Beginning Inventory (Bipi, pc)',
    'Lower Maintaining Inventory Level (LMILpi, pc)',
    'Expected Maintaining Inventory Level (EMILpi, pc)',
    'Upper Maintaining Inventory Level (UMILpi, pc)',
    'selling price (sp, Php/pc)',
    'cost (cp, Php/pc)',
    'disposal cost (disppi, Php/pc)',
    'transport cost (tpi, Php/pc)',
    'warehouse holding cost (wpi, Php/pc)',
    'transshipment cost (tspi, Php/pc)',
    'ordering cost (copi, Php/pc)',
    'Weight per unit of product (g)',
    'Sales (units)'
]

for col in columns_to_convert:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

print("Data types after conversion:")
df.info()
# Out:
# Data types after conversion:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 22 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Store Location (i)                                                       17 non-null     object
#  1   Product                                                                  32 non-null     object
#  2   Volume per unit of product (cm3)                                         30 non-null     float64
#  3   Beginning Inventory (Bipi, pc)                                           30 non-null     float64
#  4   Lower Maintaining Inventory Level (LMILpi, pc)                           30 non-null     float64
#  5   Expected Maintaining Inventory Level (EMILpi, pc)                        30 non-null     float64
# ...

# %% [markdown]
# Now that the relevant columns have been converted to numeric types, let's look at the descriptive statistics again to see the summary of these columns.

# %%
print("Descriptive statistics for numerical columns after conversion:")
display(df.describe())
# Out:
# Descriptive statistics for numerical columns after conversion:
#        Volume per unit of product (cm3)  Beginning Inventory (Bipi, pc)  \
# count                         30.000000                       30.000000
# mean                         221.200000                       77.700000
# std                          158.729308                       32.361269
# min                           54.000000                       23.000000
# 25%                           92.000000                       56.500000
# 50%                          128.000000                       72.500000
# 75%                          393.000000                       92.500000
# max                          469.000000                      154.000000
#
#        Lower Maintaining Inventory Level (LMILpi, pc)  \
# count                                       30.000000
# mean                                        46.500000
# std                                         17.832071
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1bcb4bd6-2cbb-49de-bcce-cea7e8222b29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bcb4bd6-2cbb-49de-bcce-cea7e8222b29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(os.listdir())
# Out:
# ['.config', 'extracted_data', 'Model Sample Data - Retail Inventory (1) (1).xlsx', 'Model Sample Data - Retail Inventory.xlsx', 'Model Sample Data - Retail Inventory (1).xlsx', 'Model Sample Data - Retail Inventory (3).xlsx', 'Model Sample Data - Retail Inventory (2).xlsx', 'sample_data']

# %%
print("Missing values in each column:")
display(df.isnull().sum())
# Out:
# Missing values in each column:
# Store Location (i)                                                         18
# Product                                                                     3
# Volume per unit of product (cm3)                                            5
# Beginning Inventory (Bipi, pc)                                              5
# Lower Maintaining Inventory Level (LMILpi, pc)                              5
# Expected Maintaining Inventory Level (EMILpi, pc)                           5
# Upper Maintaining Inventory Level (UMILpi, pc)                              5
# Product category (from Phase 1)                                             3
# selling price (sp, Php/pc)                                                  5
# cost (cp, Php/pc)                                                           5
# disposal cost (disppi, Php/pc)                                              5
# transport cost (tpi, Php/pc)                                                5
# ...

# %%
print("Missing values in each column:")
display(df.isnull().sum())
# Out:
# Missing values in each column:
# Store Location (i)                                                         18
# Product                                                                     3
# Volume per unit of product (cm3)                                            5
# Beginning Inventory (Bipi, pc)                                              5
# Lower Maintaining Inventory Level (LMILpi, pc)                              5
# Expected Maintaining Inventory Level (EMILpi, pc)                           5
# Upper Maintaining Inventory Level (UMILpi, pc)                              5
# Product category (from Phase 1)                                             3
# selling price (sp, Php/pc)                                                  5
# cost (cp, Php/pc)                                                           5
# disposal cost (disppi, Php/pc)                                              5
# transport cost (tpi, Php/pc)                                                5
# ...

# %%
print("First 5 rows of the DataFrame:")
display(df.head())
# Out:
# First 5 rows of the DataFrame:
#                             Store Location (i) Product  \
# 0                                            1      p1
# 1  Distance from Centralized Disposal Facility      p5
# 2                                          NaN      p8
# 3                                          NaN     p16
# 4                                          NaN     p17
#
#    Volume per unit of product (cm3)  Beginning Inventory (Bipi, pc)  \
# 0                             469.0                            30.0
# 1                              72.0                           136.0
# 2                             366.0                            48.0
# 3                             393.0                            96.0
# 4                             121.0                            23.0
#
#    Lower Maintaining Inventory Level (LMILpi, pc)  \
# 0                                            47.0
# 1                                            20.0
# ...

# %%
import os
import zipfile
import pandas as pd

# First, let's see what files are currently in your directory.
# This helps you identify the exact name of your uploaded zip file.
print("Files in current directory:")
print(os.listdir())

# --- Replace 'your_zip_file.zip' with the actual name of your zip file ---
zip_file_name = 'Retail Inventory Data (1).zip' # Example zip file name
# If you have another zip file, update this variable accordingly

# Create a directory to extract files into (optional but good practice)
extraction_path = 'extracted_data'
os.makedirs(extraction_path, exist_ok=True)

try:
    with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
        zip_ref.extractall(extraction_path)
    print(f"\nSuccessfully extracted '{zip_file_name}' to '{extraction_path}'.")

    # List files inside the extracted directory to find your data file
    print(f"\nFiles in '{extraction_path}' after extraction:")
    print(os.listdir(extraction_path))

    # --- Assuming your data is in a CSV file named 'your_data.csv' inside the zip ---
    # --- You'll need to replace 'your_data.csv' with the actual name of your data file ---
    data_file_in_zip = 'file_name_inside_zip.csv' # Example data file name
    full_file_path = os.path.join(extraction_path, data_file_in_zip)

    if os.path.exists(full_file_path):
        # Check if it's a CSV or Excel and use the appropriate pandas function
        if data_file_in_zip.endswith('.csv'):
            df_from_zip = pd.read_csv(full_file_path)
            print(f"\nSuccessfully loaded '{data_file_in_zip}' into a DataFrame.")
            display(df_from_zip.head())
        elif data_file_in_zip.endswith('.xlsx') or data_file_in_zip.endswith('.xls'):
            df_from_zip = pd.read_excel(full_file_path)
            print(f"\nSuccessfully loaded '{data_file_in_zip}' into a DataFrame.")
            display(df_from_zip.head())
        else:
            print(f"Unsupported file type for '{data_file_in_zip}'. Please load manually.")
    else:
        print(f"\nError: Data file '{data_file_in_zip}' not found in '{extraction_path}'. Please check the filename inside your zip.")

except FileNotFoundError:
    print(f"\nError: The zip file '{zip_file_name}' was not found. Please ensure it's uploaded or the name is correct.")
except Exception as e:
    print(f"\nAn unexpected error occurred: {e}")
# Out:
# Files in current directory:
# ['.config', 'extracted_data', 'Model Sample Data - Retail Inventory (1) (1).xlsx', 'Model Sample Data - Retail Inventory.xlsx', 'Model Sample Data - Retail Inventory (1).xlsx', 'Model Sample Data - Retail Inventory (3).xlsx', 'Model Sample Data - Retail Inventory (2).xlsx', 'sample_data']
#
# Error: The zip file 'Retail Inventory Data (1).zip' was not found. Please ensure it's uploaded or the name is correct.

# %%
print("First 5 rows of the DataFrame:")
display(df.head())
# Out:
# First 5 rows of the DataFrame:
#                             Store Location (i) Product  \
# 0                                            1      p1
# 1  Distance from Centralized Disposal Facility      p5
# 2                                          NaN      p8
# 3                                          NaN     p16
# 4                                          NaN     p17
#
#    Volume per unit of product (cm3)  Beginning Inventory (Bipi, pc)  \
# 0                             469.0                            30.0
# 1                              72.0                           136.0
# 2                             366.0                            48.0
# 3                             393.0                            96.0
# 4                             121.0                            23.0
#
#    Lower Maintaining Inventory Level (LMILpi, pc)  \
# 0                                            47.0
# 1                                            20.0
# ...

# %%
print("DataFrame Info (data types and non-null counts):")
df.info()
# Out:
# DataFrame Info (data types and non-null counts):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 22 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Store Location (i)                                                       17 non-null     object
#  1   Product                                                                  32 non-null     object
#  2   Volume per unit of product (cm3)                                         30 non-null     float64
#  3   Beginning Inventory (Bipi, pc)                                           30 non-null     float64
#  4   Lower Maintaining Inventory Level (LMILpi, pc)                           30 non-null     float64
#  5   Expected Maintaining Inventory Level (EMILpi, pc)                        30 non-null     float64
# ...

# %%
print("Descriptive statistics for numerical columns:")
display(df.describe())
# Out:
# Descriptive statistics for numerical columns:
#        Volume per unit of product (cm3)  Beginning Inventory (Bipi, pc)  \
# count                         30.000000                       30.000000
# mean                         221.200000                       77.700000
# std                          158.729308                       32.361269
# min                           54.000000                       23.000000
# 25%                           92.000000                       56.500000
# 50%                          128.000000                       72.500000
# 75%                          393.000000                       92.500000
# max                          469.000000                      154.000000
#
#        Lower Maintaining Inventory Level (LMILpi, pc)  \
# count                                       30.000000
# mean                                        46.500000
# std                                         17.832071
# ...
